# %% [markdown]
# # RA2CE feature: Hazard overlay

# %% [markdown]
# In this notebook, we will guide you through performing a hazard overlay with a network using RA2CE.
# This notebook follows the RA2CE_basics notebook, in which the user creates a network from OSM.
# This is needed first before being able to execute this notebook
#
# First of all, we will import the packages we need to execute the notebook:

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
from pathlib import Path
import rasterio

# %% [markdown]
# Import RA2CE by importing the RA2CEHandler

# %%
from ra2ce.ra2ce_handler import Ra2ceHandler # import the ra2cehandler to run ra2ce analyses

# %% [markdown]
# Specify the path to the folder holding your input data and where you want to store your output (use the RA2CE folder structure!)

# %%
root_dir = Path (r'C:\python\ra2ce\examples\data\hazard_overlay') #specify the path to the folder holding the RA2CE folder and input data

# %% [markdown]
# Specify the names of the initialization files and check whether they exist and can be found

# %%
_network_ini_name = "network.ini" #set the name for the network.ini

network_ini = root_dir / _network_ini_name

assert network_ini.is_file() # check whether the network.ini file exists

# %% [markdown]
# ## Hazard map
# Now we need a hazard map!
# You can use any hazard map, as long as it is in .tif format and you specify the correct projection in the network.ini file.
#
# Save the map in the static/hazard folder. If you are not familiar with the RA2CE folder structure, first open the ra2ce_basics notebook.
#
# *You can for example download flood maps from the Global Flood Database.*
#
# *Note: the hazard map needs to be in **.tif** format*

# %%
hazard_folder = root_dir / "static" / "hazard" # find the hazard folder where you locate your hazard map
hazard_map = hazard_folder / "max_flood_depth.tif" # set the name of the hazard map

# %%
# Open the TIF file using rasterio
with rasterio.open(hazard_map) as src:
    # Read the TIF file as a numpy array
    tif_array = src.read(1)  # Change the band index (1) if necessary

plt.figure(figsize=(10, 10))
plt.imshow(tif_array, cmap='Blues')  # Change the colormap if desired
plt.colorbar(label='Pixel Values')
plt.title('hazard map')
plt.show()

# %% [markdown]
# ## Network.ini file

# %% [markdown]
# To use the hazard map with RA2CE, we need to fill in the **[hazard]** section in the network.ini.
#
# Specify the hazard map name in the **hazard_map** parameter in network.ini. RA2CE expects the hazard map to be located in the *hazard* folder.
#
# Set the right CRS for the hazard map in the **hazard_crs** parameter. This CRS can be different from that of origins, destinations and the network. RA2CE will reproject the network to the CRS of the flood map and will reproject the network back to the original CRS when the CRS differs.
#
# *Advanced: If you have a hazard map with continous scale variables, the **aggregate_wl** parameter in analysis.ini can be set to either 'max', 'min' or 'mean' to take the maximum, minimum or mean value per network segment when the exposure of the network to a certain hazard (map) is determined.*<br>

# %% [markdown]
# **Network.ini content**
# <br>
# <br>
# > [project]<br>
# name = *project name*<br>
# <br>
# [network]<br>
# directed = False<br>
# source = OSM download<br>
# primary_file = None<br>
# diversion_file = None<br>
# file_id = rfid_c<br>
# polygon = map.geojson<br>
# network_type = drive<br>
# road_types = motorway,motorway_link,primary,primary_link,secondary,secondary_link,tertiary,tertiary_link<br>
# save_gpkg = True<br>
# <br>
# [origins_destinations]<br>
# origins = None<br>
# destinations = None<br>
# origins_names = None<br>
# destinations_names = None<br>
# id_name_origin_destination = None<br>
# origin_count = None<br>
# origin_out_fraction = None<br>
# category = None<br>
# <br>
# [hazard]<br>
# **hazard_map = max_flood_depth.tif**<br>
# hazard_id = None<br>
# hazard_field_name = waterdepth<br>
# **aggregate_wl = max**<br>
# **hazard_crs = EPSG:32736**<br>
# <br>
# *[cleanup]<br>
# snapping_threshold = None<br>
# segmentation_length = None<br>
# merge_lines = True<br>
# merge_on_id = False<br>
# cut_at_intersections = False<br>*

# %% [markdown]
# ## Run RA2CE

# %% [markdown]
# Now, run RA2CE using the network.ini

# %%
handler = Ra2ceHandler(network=network_ini, analysis=None)
handler.configure()
# Out:
# 2023-11-08 02:15:15 PM - [ra2ce_logging.py:41] - root - INFO - RA2CE logger initialized.
# 2023-11-08 02:15:15 PM - [ra2ce_logging.py:41] - root - INFO - RA2CE logger initialized.
# 2023-11-08 02:15:15 PM - [ra2ce_logging.py:41] - root - INFO - RA2CE logger initialized.
# 2023-11-08 02:15:15 PM - [ra2ce_logging.py:41] - root - INFO - RA2CE logger initialized.
# 2023-11-08 02:15:15 PM - [ra2ce_logging.py:41] - root - INFO - RA2CE logger initialized.
# 2023-11-08 02:15:15 PM - [ra2ce_logging.py:41] - root - INFO - RA2CE logger initialized.
# 2023-11-08 02:15:15 PM - [network_wrapper_factory.py:53] - root - INFO - Start creating a network from the submitted shapefile.
# 2023-11-08 02:15:15 PM - [network_wrapper_factory.py:53] - root - INFO - Start creating a network from the submitted shapefile.
# 2023-11-08 02:15:15 PM - [network_wrapper_factory.py:53] - root - INFO - Start creating a network from the submitted shapefile.
# 2023-11-08 02:15:15 PM - [network_wrapper_factory.py:53] - root - INFO - Start creating a network from the submitted shapefile.
# 2023-11-08 02:15:15 PM - [network_wrapper_factory.py:53] - root - INFO - Start creating a network from the submitted shapefile.
# 2023-11-08 02:15:15 PM - [network_wrapper_factory.py:53] - root - INFO - Start creating a network from the submitted shapefile.
# 2023-11-08 02:15:15 PM - [osm_network_wrapper.py:56] - root - INFO - Start downloading a network from OSM.
# 2023-11-08 02:15:15 PM - [osm_network_wrapper.py:56] - root - INFO - Start downloading a network from OSM.
# 2023-11-08 02:15:15 PM - [osm_network_wrapper.py:56] - root - INFO - Start downloading a network from OSM.
# 2023-11-08 02:15:15 PM - [osm_network_wrapper.py:56] - root - INFO - Start downloading a network from OSM.
# 2023-11-08 02:15:15 PM - [osm_network_wrapper.py:56] - root - INFO - Start downloading a network from OSM.
# 2023-11-08 02:15:15 PM - [osm_network_wrapper.py:56] - root - INFO - Start downloading a network from OSM.
# 2023-11-08 02:15:16 PM - [osm_network_wrapper.py:176] - root - INFO - graph downloaded from OSM with 844 nodes and 1,208 edges
# 2023-11-08 02:15:16 PM - [osm_network_wrapper.py:176] - root - INFO - graph downloaded from OSM with 844 nodes and 1,208 edges
# 2023-11-08 02:15:16 PM - [osm_network_wrapper.py:176] - root - INFO - graph downloaded from OSM with 844 nodes and 1,208 edges
# 2023-11-08 02:15:16 PM - [osm_network_wrapper.py:176] - root - INFO - graph downloaded from OSM with 844 nodes and 1,208 edges
# 2023-11-08 02:15:16 PM - [osm_network_wrapper.py:176] - root - INFO - graph downloaded from OSM with 844 nodes and 1,208 edges
# 2023-11-08 02:15:16 PM - [osm_network_wrapper.py:176] - root - INFO - graph downloaded from OSM with 844 nodes and 1,208 edges
# c:\Users\meije_le\Anaconda3\envs\ra2ce_env\lib\site-packages\osmnx\simplification.py:462: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   merged = utils_graph.graph_to_gdfs(G, edges=False)["geometry"].buffer(tolerance).unary_union
# c:\Users\meije_le\Anaconda3\envs\ra2ce_env\lib\site-packages\osmnx\simplification.py:510: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids = node_clusters.centroid
# 2023-11-08 02:15:17 PM - [networks_utils.py:985] - root - INFO - Simplifying graph
# 2023-11-08 02:15:17 PM - [networks_utils.py:985] - root - INFO - Simplifying graph
# 2023-11-08 02:15:17 PM - [networks_utils.py:985] - root - INFO - Simplifying graph
# 2023-11-08 02:15:17 PM - [networks_utils.py:985] - root - INFO - Simplifying graph
# 2023-11-08 02:15:17 PM - [networks_utils.py:985] - root - INFO - Simplifying graph
# 2023-11-08 02:15:17 PM - [networks_utils.py:985] - root - INFO - Simplifying graph
# 2023-11-08 02:15:17 PM - [networks_utils.py:1084] - root - INFO - Added a new unique identifier field 'rfid_c'.
# 2023-11-08 02:15:17 PM - [networks_utils.py:1084] - root - INFO - Added a new unique identifier field 'rfid_c'.
# 2023-11-08 02:15:17 PM - [networks_utils.py:1084] - root - INFO - Added a new unique identifier field 'rfid_c'.
# 2023-11-08 02:15:17 PM - [networks_utils.py:1084] - root - INFO - Added a new unique identifier field 'rfid_c'.
# 2023-11-08 02:15:17 PM - [networks_utils.py:1084] - root - INFO - Added a new unique identifier field 'rfid_c'.
# 2023-11-08 02:15:17 PM - [networks_utils.py:1084] - root - INFO - Added a new unique identifier field 'rfid_c'.
# 2023-11-08 02:15:17 PM - [networks_utils.py:1117] - root - INFO - Graph simplified from 844 to 151 nodes and 1,208 to 251 edges.
# 2023-11-08 02:15:17 PM - [networks_utils.py:1117] - root - INFO - Graph simplified from 844 to 151 nodes and 1,208 to 251 edges.
# 2023-11-08 02:15:17 PM - [networks_utils.py:1117] - root - INFO - Graph simplified from 844 to 151 nodes and 1,208 to 251 edges.
# 2023-11-08 02:15:17 PM - [networks_utils.py:1117] - root - INFO - Graph simplified from 844 to 151 nodes and 1,208 to 251 edges.
# 2023-11-08 02:15:17 PM - [networks_utils.py:1117] - root - INFO - Graph simplified from 844 to 151 nodes and 1,208 to 251 edges.
# 2023-11-08 02:15:17 PM - [networks_utils.py:1117] - root - INFO - Graph simplified from 844 to 151 nodes and 1,208 to 251 edges.
# 2023-11-08 02:15:17 PM - [networks_utils.py:1084] - root - INFO - Added a new unique identifier field 'rfid'.
# 2023-11-08 02:15:17 PM - [networks_utils.py:1084] - root - INFO - Added a new unique identifier field 'rfid'.
# 2023-11-08 02:15:17 PM - [networks_utils.py:1084] - root - INFO - Added a new unique identifier field 'rfid'.
# 2023-11-08 02:15:17 PM - [networks_utils.py:1084] - root - INFO - Added a new unique identifier field 'rfid'.
# 2023-11-08 02:15:17 PM - [networks_utils.py:1084] - root - INFO - Added a new unique identifier field 'rfid'.
# 2023-11-08 02:15:17 PM - [networks_utils.py:1084] - root - INFO - Added a new unique identifier field 'rfid'.
# 100%|██████████| 251/251 [00:00<?, ?it/s]
# 2023-11-08 02:15:17 PM - [networks_utils.py:1520] - root - INFO - Lookup tables from complex to simple and vice versa were created
# 2023-11-08 02:15:17 PM - [networks_utils.py:1520] - root - INFO - Lookup tables from complex to simple and vice versa were created
# 2023-11-08 02:15:17 PM - [networks_utils.py:1520] - root - INFO - Lookup tables from complex to simple and vice versa were created
# 2023-11-08 02:15:17 PM - [networks_utils.py:1520] - root - INFO - Lookup tables from complex to simple and vice versa were created
# 2023-11-08 02:15:17 PM - [networks_utils.py:1520] - root - INFO - Lookup tables from complex to simple and vice versa were created
# 2023-11-08 02:15:17 PM - [networks_utils.py:1520] - root - INFO - Lookup tables from complex to simple and vice versa were created
# 2023-11-08 02:15:17 PM - [networks_utils.py:1003] - root - INFO - Simplified graph succesfully created
# 2023-11-08 02:15:17 PM - [networks_utils.py:1003] - root - INFO - Simplified graph succesfully created
# 2023-11-08 02:15:17 PM - [networks_utils.py:1003] - root - INFO - Simplified graph succesfully created
# 2023-11-08 02:15:17 PM - [networks_utils.py:1003] - root - INFO - Simplified graph succesfully created
# 2023-11-08 02:15:17 PM - [networks_utils.py:1003] - root - INFO - Simplified graph succesfully created
# 2023-11-08 02:15:17 PM - [networks_utils.py:1003] - root - INFO - Simplified graph succesfully created
# 2023-11-08 02:15:17 PM - [osm_network_wrapper.py:65] - root - INFO - Start converting the graph to a geodataframe
# 2023-11-08 02:15:17 PM - [osm_network_wrapper.py:65] - root - INFO - Start converting the graph to a geodataframe
# 2023-11-08 02:15:17 PM - [osm_network_wrapper.py:65] - root - INFO - Start converting the graph to a geodataframe
# 2023-11-08 02:15:17 PM - [osm_network_wrapper.py:65] - root - INFO - Start converting the graph to a geodataframe
# 2023-11-08 02:15:17 PM - [osm_network_wrapper.py:65] - root - INFO - Start converting the graph to a geodataframe
# 2023-11-08 02:15:17 PM - [osm_network_wrapper.py:65] - root - INFO - Start converting the graph to a geodataframe
# 2023-11-08 02:15:17 PM - [osm_network_wrapper.py:67] - root - INFO - Finished converting the graph to a geodataframe
# 2023-11-08 02:15:17 PM - [osm_network_wrapper.py:67] - root - INFO - Finished converting the graph to a geodataframe
# 2023-11-08 02:15:17 PM - [osm_network_wrapper.py:67] - root - INFO - Finished converting the graph to a geodataframe
# 2023-11-08 02:15:17 PM - [osm_network_wrapper.py:67] - root - INFO - Finished converting the graph to a geodataframe
# 2023-11-08 02:15:17 PM - [osm_network_wrapper.py:67] - root - INFO - Finished converting the graph to a geodataframe
# 2023-11-08 02:15:17 PM - [osm_network_wrapper.py:67] - root - INFO - Finished converting the graph to a geodataframe
# 2023-11-08 02:15:18 PM - [json_exporter.py:46] - root - INFO - Saved (or overwrote) simple_to_complex.json
# 2023-11-08 02:15:18 PM - [json_exporter.py:46] - root - INFO - Saved (or overwrote) simple_to_complex.json
# 2023-11-08 02:15:18 PM - [json_exporter.py:46] - root - INFO - Saved (or overwrote) simple_to_complex.json
# 2023-11-08 02:15:18 PM - [json_exporter.py:46] - root - INFO - Saved (or overwrote) simple_to_complex.json
# 2023-11-08 02:15:18 PM - [json_exporter.py:46] - root - INFO - Saved (or overwrote) simple_to_complex.json
# 2023-11-08 02:15:18 PM - [json_exporter.py:46] - root - INFO - Saved (or overwrote) simple_to_complex.json
# 2023-11-08 02:15:18 PM - [json_exporter.py:46] - root - INFO - Saved (or overwrote) complex_to_simple.json
# 2023-11-08 02:15:18 PM - [json_exporter.py:46] - root - INFO - Saved (or overwrote) complex_to_simple.json
# 2023-11-08 02:15:18 PM - [json_exporter.py:46] - root - INFO - Saved (or overwrote) complex_to_simple.json
# 2023-11-08 02:15:18 PM - [json_exporter.py:46] - root - INFO - Saved (or overwrote) complex_to_simple.json
# 2023-11-08 02:15:18 PM - [json_exporter.py:46] - root - INFO - Saved (or overwrote) complex_to_simple.json
# 2023-11-08 02:15:18 PM - [json_exporter.py:46] - root - INFO - Saved (or overwrote) complex_to_simple.json
# 2023-11-08 02:15:18 PM - [networks_utils.py:1649] - root - INFO - Not all of the edges contain a 'maxspeed' attribute. RA2CE will guess the right average maximum speed per road type that does not contain a 'maxspeed' attribute. Please check the average speed CSV to ensure correct speeds here: C:\python\ra2ce\examples\data\hazard_overlay\static\output_graph\avg_speed.csv
# 2023-11-08 02:15:18 PM - [networks_utils.py:1649] - root - INFO - Not all of the edges contain a 'maxspeed' attribute. RA2CE will guess the right average maximum speed per road type that does not contain a 'maxspeed' attribute. Please check the average speed CSV to ensure correct speeds here: C:\python\ra2ce\examples\data\hazard_overlay\static\output_graph\avg_speed.csv
# 2023-11-08 02:15:18 PM - [networks_utils.py:1649] - root - INFO - Not all of the edges contain a 'maxspeed' attribute. RA2CE will guess the right average maximum speed per road type that does not contain a 'maxspeed' attribute. Please check the average speed CSV to ensure correct speeds here: C:\python\ra2ce\examples\data\hazard_overlay\static\output_graph\avg_speed.csv
# 2023-11-08 02:15:18 PM - [networks_utils.py:1649] - root - INFO - Not all of the edges contain a 'maxspeed' attribute. RA2CE will guess the right average maximum speed per road type that does not contain a 'maxspeed' attribute. Please check the average speed CSV to ensure correct speeds here: C:\python\ra2ce\examples\data\hazard_overlay\static\output_graph\avg_speed.csv
# 2023-11-08 02:15:18 PM - [networks_utils.py:1649] - root - INFO - Not all of the edges contain a 'maxspeed' attribute. RA2CE will guess the right average maximum speed per road type that does not contain a 'maxspeed' attribute. Please check the average speed CSV to ensure correct speeds here: C:\python\ra2ce\examples\data\hazard_overlay\static\output_graph\avg_speed.csv
# 2023-11-08 02:15:18 PM - [networks_utils.py:1649] - root - INFO - Not all of the edges contain a 'maxspeed' attribute. RA2CE will guess the right average maximum speed per road type that does not contain a 'maxspeed' attribute. Please check the average speed CSV to ensure correct speeds here: C:\python\ra2ce\examples\data\hazard_overlay\static\output_graph\avg_speed.csv
# C:\python\ra2ce\ra2ce\graph\networks_utils.py:1666: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["avg_speed"].iloc[i] = df.loc[
# 2023-11-08 02:15:18 PM - [networks_utils.py:1680] - root - INFO - Saved the average speeds per road type to: C:\python\ra2ce\examples\data\hazard_overlay\static\output_graph\avg_speed.csv
# 2023-11-08 02:15:18 PM - [networks_utils.py:1680] - root - INFO - Saved the average speeds per road type to: C:\python\ra2ce\examples\data\hazard_overlay\static\output_graph\avg_speed.csv
# 2023-11-08 02:15:18 PM - [networks_utils.py:1680] - root - INFO - Saved the average speeds per road type to: C:\python\ra2ce\examples\data\hazard_overlay\static\output_graph\avg_speed.csv
# 2023-11-08 02:15:18 PM - [networks_utils.py:1680] - root - INFO - Saved the average speeds per road type to: C:\python\ra2ce\examples\data\hazard_overlay\static\output_graph\avg_speed.csv
# 2023-11-08 02:15:18 PM - [networks_utils.py:1680] - root - INFO - Saved the average speeds per road type to: C:\python\ra2ce\examples\data\hazard_overlay\static\output_graph\avg_speed.csv
# 2023-11-08 02:15:18 PM - [networks_utils.py:1680] - root - INFO - Saved the average speeds per road type to: C:\python\ra2ce\examples\data\hazard_overlay\static\output_graph\avg_speed.csv
# C:\python\ra2ce\ra2ce\graph\network_wrappers\osm_network_wrapper\osm_network_wrapper.py:101: RuntimeWarning: divide by zero encountered in scalar divide
#   hours = (edata["length"] / 1000) / edata["avgspeed"]
# 2023-11-08 02:15:19 PM - [multi_graph_network_exporter.py:56] - root - INFO - Saved base_graph in C:\python\ra2ce\examples\data\hazard_overlay\static\output_graph.
# 2023-11-08 02:15:19 PM - [multi_graph_network_exporter.py:56] - root - INFO - Saved base_graph in C:\python\ra2ce\examples\data\hazard_overlay\static\output_graph.
# 2023-11-08 02:15:19 PM - [multi_graph_network_exporter.py:56] - root - INFO - Saved base_graph in C:\python\ra2ce\examples\data\hazard_overlay\static\output_graph.
# 2023-11-08 02:15:19 PM - [multi_graph_network_exporter.py:56] - root - INFO - Saved base_graph in C:\python\ra2ce\examples\data\hazard_overlay\static\output_graph.
# 2023-11-08 02:15:19 PM - [multi_graph_network_exporter.py:56] - root - INFO - Saved base_graph in C:\python\ra2ce\examples\data\hazard_overlay\static\output_graph.
# 2023-11-08 02:15:19 PM - [multi_graph_network_exporter.py:56] - root - INFO - Saved base_graph in C:\python\ra2ce\examples\data\hazard_overlay\static\output_graph.
# 2023-11-08 02:15:19 PM - [networks_utils.py:1214] - root - INFO - Saving nodes as shapefile: C:\python\ra2ce\examples\data\hazard_overlay\static\output_graph\base_graph_nodes.gpkg
# 2023-11-08 02:15:19 PM - [networks_utils.py:1214] - root - INFO - Saving nodes as shapefile: C:\python\ra2ce\examples\data\hazard_overlay\static\output_graph\base_graph_nodes.gpkg
# 2023-11-08 02:15:19 PM - [networks_utils.py:1214] - root - INFO - Saving nodes as shapefile: C:\python\ra2ce\examples\data\hazard_overlay\static\output_graph\base_graph_nodes.gpkg
# 2023-11-08 02:15:19 PM - [networks_utils.py:1214] - root - INFO - Saving nodes as shapefile: C:\python\ra2ce\examples\data\hazard_overlay\static\output_graph\base_graph_nodes.gpkg
# 2023-11-08 02:15:19 PM - [networks_utils.py:1214] - root - INFO - Saving nodes as shapefile: C:\python\ra2ce\examples\data\hazard_overlay\static\output_graph\base_graph_nodes.gpkg
# 2023-11-08 02:15:19 PM - [networks_utils.py:1214] - root - INFO - Saving nodes as shapefile: C:\python\ra2ce\examples\data\hazard_overlay\static\output_graph\base_graph_nodes.gpkg
# 2023-11-08 02:15:19 PM - [networks_utils.py:1215] - root - INFO - Saving edges as shapefile: C:\python\ra2ce\examples\data\hazard_overlay\static\output_graph\base_graph_edges.gpkg
# 2023-11-08 02:15:19 PM - [networks_utils.py:1215] - root - INFO - Saving edges as shapefile: C:\python\ra2ce\examples\data\hazard_overlay\static\output_graph\base_graph_edges.gpkg
# 2023-11-08 02:15:19 PM - [networks_utils.py:1215] - root - INFO - Saving edges as shapefile: C:\python\ra2ce\examples\data\hazard_overlay\static\output_graph\base_graph_edges.gpkg
# 2023-11-08 02:15:19 PM - [networks_utils.py:1215] - root - INFO - Saving edges as shapefile: C:\python\ra2ce\examples\data\hazard_overlay\static\output_graph\base_graph_edges.gpkg
# 2023-11-08 02:15:19 PM - [networks_utils.py:1215] - root - INFO - Saving edges as shapefile: C:\python\ra2ce\examples\data\hazard_overlay\static\output_graph\base_graph_edges.gpkg
# 2023-11-08 02:15:19 PM - [networks_utils.py:1215] - root - INFO - Saving edges as shapefile: C:\python\ra2ce\examples\data\hazard_overlay\static\output_graph\base_graph_edges.gpkg
# 2023-11-08 02:15:19 PM - [multi_graph_network_exporter.py:48] - root - INFO - Saved base_graph_edges.gpkg and base_graph_nodes.gpkg in C:\python\ra2ce\examples\data\hazard_overlay\static\output_graph.
# 2023-11-08 02:15:19 PM - [multi_graph_network_exporter.py:48] - root - INFO - Saved base_graph_edges.gpkg and base_graph_nodes.gpkg in C:\python\ra2ce\examples\data\hazard_overlay\static\output_graph.
# 2023-11-08 02:15:19 PM - [multi_graph_network_exporter.py:48] - root - INFO - Saved base_graph_edges.gpkg and base_graph_nodes.gpkg in C:\python\ra2ce\examples\data\hazard_overlay\static\output_graph.
# 2023-11-08 02:15:19 PM - [multi_graph_network_exporter.py:48] - root - INFO - Saved base_graph_edges.gpkg and base_graph_nodes.gpkg in C:\python\ra2ce\examples\data\hazard_overlay\static\output_graph.
# 2023-11-08 02:15:19 PM - [multi_graph_network_exporter.py:48] - root - INFO - Saved base_graph_edges.gpkg and base_graph_nodes.gpkg in C:\python\ra2ce\examples\data\hazard_overlay\static\output_graph.
# 2023-11-08 02:15:19 PM - [multi_graph_network_exporter.py:48] - root - INFO - Saved base_graph_edges.gpkg and base_graph_nodes.gpkg in C:\python\ra2ce\examples\data\hazard_overlay\static\output_graph.
# 2023-11-08 02:15:19 PM - [geodataframe_network_exporter.py:42] - root - INFO - Saved base_network in C:\python\ra2ce\examples\data\hazard_overlay\static\output_graph.
# 2023-11-08 02:15:19 PM - [geodataframe_network_exporter.py:42] - root - INFO - Saved base_network in C:\python\ra2ce\examples\data\hazard_overlay\static\output_graph.
# 2023-11-08 02:15:19 PM - [geodataframe_network_exporter.py:42] - root - INFO - Saved base_network in C:\python\ra2ce\examples\data\hazard_overlay\static\output_graph.
# 2023-11-08 02:15:19 PM - [geodataframe_network_exporter.py:42] - root - INFO - Saved base_network in C:\python\ra2ce\examples\data\hazard_overlay\static\output_graph.
# 2023-11-08 02:15:19 PM - [geodataframe_network_exporter.py:42] - root - INFO - Saved base_network in C:\python\ra2ce\examples\data\hazard_overlay\static\output_graph.
# 2023-11-08 02:15:19 PM - [geodataframe_network_exporter.py:42] - root - INFO - Saved base_network in C:\python\ra2ce\examples\data\hazard_overlay\static\output_graph.
# 2023-11-08 02:15:19 PM - [geodataframe_network_exporter.py:37] - root - INFO - Saved base_network in C:\python\ra2ce\examples\data\hazard_overlay\static\output_graph.
# 2023-11-08 02:15:19 PM - [geodataframe_network_exporter.py:37] - root - INFO - Saved base_network in C:\python\ra2ce\examples\data\hazard_overlay\static\output_graph.
# 2023-11-08 02:15:19 PM - [geodataframe_network_exporter.py:37] - root - INFO - Saved base_network in C:\python\ra2ce\examples\data\hazard_overlay\static\output_graph.
# 2023-11-08 02:15:19 PM - [geodataframe_network_exporter.py:37] - root - INFO - Saved base_network in C:\python\ra2ce\examples\data\hazard_overlay\static\output_graph.
# 2023-11-08 02:15:19 PM - [geodataframe_network_exporter.py:37] - root - INFO - Saved base_network in C:\python\ra2ce\examples\data\hazard_overlay\static\output_graph.
# 2023-11-08 02:15:19 PM - [geodataframe_network_exporter.py:37] - root - INFO - Saved base_network in C:\python\ra2ce\examples\data\hazard_overlay\static\output_graph.
# 2023-11-08 02:15:19 PM - [hazard_overlay.py:102] - root - INFO - Initialized hazard object.
# 2023-11-08 02:15:19 PM - [hazard_overlay.py:102] - root - INFO - Initialized hazard object.
# 2023-11-08 02:15:19 PM - [hazard_overlay.py:102] - root - INFO - Initialized hazard object.
# 2023-11-08 02:15:19 PM - [hazard_overlay.py:102] - root - INFO - Initialized hazard object.
# 2023-11-08 02:15:19 PM - [hazard_overlay.py:102] - root - INFO - Initialized hazard object.
# 2023-11-08 02:15:19 PM - [hazard_overlay.py:102] - root - INFO - Initialized hazard object.
# 2023-11-08 02:15:19 PM - [hazard_overlay.py:592] - root - WARNING - Hazard crs EPSG:32736 and graph crs EPSG:4326 are inconsistent,
#                                                   we try to reproject the graph crs
# 2023-11-08 02:15:19 PM - [hazard_overlay.py:592] - root - WARNING - Hazard crs EPSG:32736 and graph crs EPSG:4326 are inconsistent,
#                                                   we try to reproject the graph crs
# 2023-11-08 02:15:19 PM - [hazard_overlay.py:592] - root - WARNING - Hazard crs EPSG:32736 and graph crs EPSG:4326 are inconsistent,
#                                                   we try to reproject the graph crs
# 2023-11-08 02:15:19 PM - [hazard_overlay.py:592] - root - WARNING - Hazard crs EPSG:32736 and graph crs EPSG:4326 are inconsistent,
#                                                   we try to reproject the graph crs
# 2023-11-08 02:15:19 PM - [hazard_overlay.py:592] - root - WARNING - Hazard crs EPSG:32736 and graph crs EPSG:4326 are inconsistent,
#                                                   we try to reproject the graph crs
# 2023-11-08 02:15:19 PM - [hazard_overlay.py:592] - root - WARNING - Hazard crs EPSG:32736 and graph crs EPSG:4326 are inconsistent,
#                                                   we try to reproject the graph crs
# 2023-11-08 02:15:19 PM - [hazard_overlay.py:478] - root - INFO - Graph extent before reprojecting: (34.8365989, 34.8999908, -19.8513266, -19.815476)
# 2023-11-08 02:15:19 PM - [hazard_overlay.py:478] - root - INFO - Graph extent before reprojecting: (34.8365989, 34.8999908, -19.8513266, -19.815476)
# 2023-11-08 02:15:19 PM - [hazard_overlay.py:478] - root - INFO - Graph extent before reprojecting: (34.8365989, 34.8999908, -19.8513266, -19.815476)
# 2023-11-08 02:15:19 PM - [hazard_overlay.py:478] - root - INFO - Graph extent before reprojecting: (34.8365989, 34.8999908, -19.8513266, -19.815476)
# 2023-11-08 02:15:19 PM - [hazard_overlay.py:478] - root - INFO - Graph extent before reprojecting: (34.8365989, 34.8999908, -19.8513266, -19.815476)
# 2023-11-08 02:15:19 PM - [hazard_overlay.py:478] - root - INFO - Graph extent before reprojecting: (34.8365989, 34.8999908, -19.8513266, -19.815476)
# 2023-11-08 02:15:19 PM - [hazard_overlay.py:481] - root - INFO - Graph extent after reprojecting: (692352.3775942898, 698980.0168438741, 7803880.058641912, 7807872.067014577)
# 2023-11-08 02:15:19 PM - [hazard_overlay.py:481] - root - INFO - Graph extent after reprojecting: (692352.3775942898, 698980.0168438741, 7803880.058641912, 7807872.067014577)
# 2023-11-08 02:15:19 PM - [hazard_overlay.py:481] - root - INFO - Graph extent after reprojecting: (692352.3775942898, 698980.0168438741, 7803880.058641912, 7807872.067014577)
# 2023-11-08 02:15:19 PM - [hazard_overlay.py:481] - root - INFO - Graph extent after reprojecting: (692352.3775942898, 698980.0168438741, 7803880.058641912, 7807872.067014577)
# 2023-11-08 02:15:19 PM - [hazard_overlay.py:481] - root - INFO - Graph extent after reprojecting: (692352.3775942898, 698980.0168438741, 7803880.058641912, 7807872.067014577)
# 2023-11-08 02:15:19 PM - [hazard_overlay.py:481] - root - INFO - Graph extent after reprojecting: (692352.3775942898, 698980.0168438741, 7803880.058641912, 7807872.067014577)
# Graph hazard overlay with max_flood_depth: 100%|██████████| 220/220 [00:02<00:00, 109.67it/s]
# Graph fraction with hazard overlay with max_flood_depth: 100%|██████████| 220/220 [00:18<00:00, 11.65it/s]
# 2023-11-08 02:15:40 PM - [multi_graph_network_exporter.py:56] - root - INFO - Saved base_graph_hazard in C:\python\ra2ce\examples\data\hazard_overlay\static\output_graph.
# 2023-11-08 02:15:40 PM - [multi_graph_network_exporter.py:56] - root - INFO - Saved base_graph_hazard in C:\python\ra2ce\examples\data\hazard_overlay\static\output_graph.
# 2023-11-08 02:15:40 PM - [multi_graph_network_exporter.py:56] - root - INFO - Saved base_graph_hazard in C:\python\ra2ce\examples\data\hazard_overlay\static\output_graph.
# 2023-11-08 02:15:40 PM - [multi_graph_network_exporter.py:56] - root - INFO - Saved base_graph_hazard in C:\python\ra2ce\examples\data\hazard_overlay\static\output_graph.
# 2023-11-08 02:15:40 PM - [multi_graph_network_exporter.py:56] - root - INFO - Saved base_graph_hazard in C:\python\ra2ce\examples\data\hazard_overlay\static\output_graph.
# 2023-11-08 02:15:40 PM - [multi_graph_network_exporter.py:56] - root - INFO - Saved base_graph_hazard in C:\python\ra2ce\examples\data\hazard_overlay\static\output_graph.
# 2023-11-08 02:15:40 PM - [networks_utils.py:1214] - root - INFO - Saving nodes as shapefile: C:\python\ra2ce\examples\data\hazard_overlay\static\output_graph\base_graph_hazard_nodes.gpkg
# 2023-11-08 02:15:40 PM - [networks_utils.py:1214] - root - INFO - Saving nodes as shapefile: C:\python\ra2ce\examples\data\hazard_overlay\static\output_graph\base_graph_hazard_nodes.gpkg
# 2023-11-08 02:15:40 PM - [networks_utils.py:1214] - root - INFO - Saving nodes as shapefile: C:\python\ra2ce\examples\data\hazard_overlay\static\output_graph\base_graph_hazard_nodes.gpkg
# 2023-11-08 02:15:40 PM - [networks_utils.py:1214] - root - INFO - Saving nodes as shapefile: C:\python\ra2ce\examples\data\hazard_overlay\static\output_graph\base_graph_hazard_nodes.gpkg
# 2023-11-08 02:15:40 PM - [networks_utils.py:1214] - root - INFO - Saving nodes as shapefile: C:\python\ra2ce\examples\data\hazard_overlay\static\output_graph\base_graph_hazard_nodes.gpkg
# 2023-11-08 02:15:40 PM - [networks_utils.py:1214] - root - INFO - Saving nodes as shapefile: C:\python\ra2ce\examples\data\hazard_overlay\static\output_graph\base_graph_hazard_nodes.gpkg
# 2023-11-08 02:15:40 PM - [networks_utils.py:1215] - root - INFO - Saving edges as shapefile: C:\python\ra2ce\examples\data\hazard_overlay\static\output_graph\base_graph_hazard_edges.gpkg
# 2023-11-08 02:15:40 PM - [networks_utils.py:1215] - root - INFO - Saving edges as shapefile: C:\python\ra2ce\examples\data\hazard_overlay\static\output_graph\base_graph_hazard_edges.gpkg
# 2023-11-08 02:15:40 PM - [networks_utils.py:1215] - root - INFO - Saving edges as shapefile: C:\python\ra2ce\examples\data\hazard_overlay\static\output_graph\base_graph_hazard_edges.gpkg
# 2023-11-08 02:15:40 PM - [networks_utils.py:1215] - root - INFO - Saving edges as shapefile: C:\python\ra2ce\examples\data\hazard_overlay\static\output_graph\base_graph_hazard_edges.gpkg
# 2023-11-08 02:15:40 PM - [networks_utils.py:1215] - root - INFO - Saving edges as shapefile: C:\python\ra2ce\examples\data\hazard_overlay\static\output_graph\base_graph_hazard_edges.gpkg
# 2023-11-08 02:15:40 PM - [networks_utils.py:1215] - root - INFO - Saving edges as shapefile: C:\python\ra2ce\examples\data\hazard_overlay\static\output_graph\base_graph_hazard_edges.gpkg
# 2023-11-08 02:15:40 PM - [multi_graph_network_exporter.py:48] - root - INFO - Saved base_graph_hazard_edges.gpkg and base_graph_hazard_nodes.gpkg in C:\python\ra2ce\examples\data\hazard_overlay\static\output_graph.
# 2023-11-08 02:15:40 PM - [multi_graph_network_exporter.py:48] - root - INFO - Saved base_graph_hazard_edges.gpkg and base_graph_hazard_nodes.gpkg in C:\python\ra2ce\examples\data\hazard_overlay\static\output_graph.
# 2023-11-08 02:15:40 PM - [multi_graph_network_exporter.py:48] - root - INFO - Saved base_graph_hazard_edges.gpkg and base_graph_hazard_nodes.gpkg in C:\python\ra2ce\examples\data\hazard_overlay\static\output_graph.
# 2023-11-08 02:15:40 PM - [multi_graph_network_exporter.py:48] - root - INFO - Saved base_graph_hazard_edges.gpkg and base_graph_hazard_nodes.gpkg in C:\python\ra2ce\examples\data\hazard_overlay\static\output_graph.
# 2023-11-08 02:15:40 PM - [multi_graph_network_exporter.py:48] - root - INFO - Saved base_graph_hazard_edges.gpkg and base_graph_hazard_nodes.gpkg in C:\python\ra2ce\examples\data\hazard_overlay\static\output_graph.
# 2023-11-08 02:15:40 PM - [multi_graph_network_exporter.py:48] - root - INFO - Saved base_graph_hazard_edges.gpkg and base_graph_hazard_nodes.gpkg in C:\python\ra2ce\examples\data\hazard_overlay\static\output_graph.
# 2023-11-08 02:15:40 PM - [hazard_overlay.py:727] - root - INFO - Iterating overlay of GeoPandas Dataframe.
# 2023-11-08 02:15:40 PM - [hazard_overlay.py:727] - root - INFO - Iterating overlay of GeoPandas Dataframe.
# 2023-11-08 02:15:40 PM - [hazard_overlay.py:727] - root - INFO - Iterating overlay of GeoPandas Dataframe.
# 2023-11-08 02:15:40 PM - [hazard_overlay.py:727] - root - INFO - Iterating overlay of GeoPandas Dataframe.
# 2023-11-08 02:15:40 PM - [hazard_overlay.py:727] - root - INFO - Iterating overlay of GeoPandas Dataframe.
# 2023-11-08 02:15:40 PM - [hazard_overlay.py:727] - root - INFO - Iterating overlay of GeoPandas Dataframe.
# 2023-11-08 02:15:40 PM - [hazard_overlay.py:735] - root - WARNING - Hazard crs EPSG:32736 and gdf crs epsg:4326 are inconsistent,
#                                                 we try to reproject the gdf crs
# 2023-11-08 02:15:40 PM - [hazard_overlay.py:735] - root - WARNING - Hazard crs EPSG:32736 and gdf crs epsg:4326 are inconsistent,
#                                                 we try to reproject the gdf crs
# 2023-11-08 02:15:40 PM - [hazard_overlay.py:735] - root - WARNING - Hazard crs EPSG:32736 and gdf crs epsg:4326 are inconsistent,
#                                                 we try to reproject the gdf crs
# 2023-11-08 02:15:40 PM - [hazard_overlay.py:735] - root - WARNING - Hazard crs EPSG:32736 and gdf crs epsg:4326 are inconsistent,
#                                                 we try to reproject the gdf crs
# 2023-11-08 02:15:40 PM - [hazard_overlay.py:735] - root - WARNING - Hazard crs EPSG:32736 and gdf crs epsg:4326 are inconsistent,
#                                                 we try to reproject the gdf crs
# 2023-11-08 02:15:40 PM - [hazard_overlay.py:735] - root - WARNING - Hazard crs EPSG:32736 and gdf crs epsg:4326 are inconsistent,
#                                                 we try to reproject the gdf crs
# 2023-11-08 02:15:40 PM - [hazard_overlay.py:742] - root - INFO - Gdf extent before reprojecting: [ 34.8365989 -19.8513266  34.8999908 -19.815476 ]
# 2023-11-08 02:15:40 PM - [hazard_overlay.py:742] - root - INFO - Gdf extent before reprojecting: [ 34.8365989 -19.8513266  34.8999908 -19.815476 ]
# 2023-11-08 02:15:40 PM - [hazard_overlay.py:742] - root - INFO - Gdf extent before reprojecting: [ 34.8365989 -19.8513266  34.8999908 -19.815476 ]
# 2023-11-08 02:15:40 PM - [hazard_overlay.py:742] - root - INFO - Gdf extent before reprojecting: [ 34.8365989 -19.8513266  34.8999908 -19.815476 ]
# 2023-11-08 02:15:40 PM - [hazard_overlay.py:742] - root - INFO - Gdf extent before reprojecting: [ 34.8365989 -19.8513266  34.8999908 -19.815476 ]
# 2023-11-08 02:15:40 PM - [hazard_overlay.py:742] - root - INFO - Gdf extent before reprojecting: [ 34.8365989 -19.8513266  34.8999908 -19.815476 ]
# 2023-11-08 02:15:40 PM - [hazard_overlay.py:745] - root - INFO - Gdf extent after reprojecting: [ 692352.37759429 7803880.05864191  698980.01684387 7807872.06701458]
# 2023-11-08 02:15:40 PM - [hazard_overlay.py:745] - root - INFO - Gdf extent after reprojecting: [ 692352.37759429 7803880.05864191  698980.01684387 7807872.06701458]
# 2023-11-08 02:15:40 PM - [hazard_overlay.py:745] - root - INFO - Gdf extent after reprojecting: [ 692352.37759429 7803880.05864191  698980.01684387 7807872.06701458]
# 2023-11-08 02:15:40 PM - [hazard_overlay.py:745] - root - INFO - Gdf extent after reprojecting: [ 692352.37759429 7803880.05864191  698980.01684387 7807872.06701458]
# 2023-11-08 02:15:40 PM - [hazard_overlay.py:745] - root - INFO - Gdf extent after reprojecting: [ 692352.37759429 7803880.05864191  698980.01684387 7807872.06701458]
# 2023-11-08 02:15:40 PM - [hazard_overlay.py:745] - root - INFO - Gdf extent after reprojecting: [ 692352.37759429 7803880.05864191  698980.01684387 7807872.06701458]
# 2023-11-08 02:15:40 PM - [hazard_intersect_builder_for_tif.py:181] - root - WARNING - Some geometries have NoneType objects (no coordinate information), namely: Empty GeoDataFrame
# Columns: [osmid, oneway, highway, reversed, length, rfid_c, rfid, name, maxspeed, lanes, ref, junction, bridge, geometry]
# Index: [].This could be due to segmentation, and might cause an exception in hazard overlay
# 2023-11-08 02:15:40 PM - [hazard_intersect_builder_for_tif.py:181] - root - WARNING - Some geometries have NoneType objects (no coordinate information), namely: Empty GeoDataFrame
# Columns: [osmid, oneway, highway, reversed, length, rfid_c, rfid, name, maxspeed, lanes, ref, junction, bridge, geometry]
# Index: [].This could be due to segmentation, and might cause an exception in hazard overlay
# 2023-11-08 02:15:40 PM - [hazard_intersect_builder_for_tif.py:181] - root - WARNING - Some geometries have NoneType objects (no coordinate information), namely: Empty GeoDataFrame
# Columns: [osmid, oneway, highway, reversed, length, rfid_c, rfid, name, maxspeed, lanes, ref, junction, bridge, geometry]
# Index: [].This could be due to segmentation, and might cause an exception in hazard overlay
# 2023-11-08 02:15:40 PM - [hazard_intersect_builder_for_tif.py:181] - root - WARNING - Some geometries have NoneType objects (no coordinate information), namely: Empty GeoDataFrame
# Columns: [osmid, oneway, highway, reversed, length, rfid_c, rfid, name, maxspeed, lanes, ref, junction, bridge, geometry]
# Index: [].This could be due to segmentation, and might cause an exception in hazard overlay
# 2023-11-08 02:15:40 PM - [hazard_intersect_builder_for_tif.py:181] - root - WARNING - Some geometries have NoneType objects (no coordinate information), namely: Empty GeoDataFrame
# Columns: [osmid, oneway, highway, reversed, length, rfid_c, rfid, name, maxspeed, lanes, ref, junction, bridge, geometry]
# Index: [].This could be due to segmentation, and might cause an exception in hazard overlay
# 2023-11-08 02:15:40 PM - [hazard_intersect_builder_for_tif.py:181] - root - WARNING - Some geometries have NoneType objects (no coordinate information), namely: Empty GeoDataFrame
# Columns: [osmid, oneway, highway, reversed, length, rfid_c, rfid, name, maxspeed, lanes, ref, junction, bridge, geometry]
# Index: [].This could be due to segmentation, and might cause an exception in hazard overlay
# Network hazard overlay with max_flood_depth: 100%|██████████| 1208/1208 [00:13<00:00, 89.96it/s]
# Network fraction with hazard overlay with max_flood_depth: 100%|██████████| 1208/1208 [00:15<00:00, 78.30it/s]

# %% [markdown]
# ## Results

# %% [markdown]
# You can run a RA2CE analysis only performing a hazard overlay. The results can be found in the output_graph folder. The data with *'\*_hazard'*, contains the result of the overlay with the hazard. Here, we will load the data from the example graph folder.
#
# Notice the column **EV1_ma**. This refers to the hazard. This column holds the water depth of the road segment. 'EV1' stands for 'Event 1' (you can run multiple hzard maps, the column results will be called EV1, EV2, EV3, etc.). '_ma' refers to maximum flood depth, which is the parameter specified in the network.ini.
#
# *When performing RA2CE with flooding and a road network, we often use the maximum water depth for the analysis because a vehicle can only use a road segment when it can drive through the largest water depth on that road segment.*

# %% [markdown]
# *Note: when there is an existing base_graph in the output_graph folder, RA2CE will always use this. However, it can be that you want to update something to that base_graph. In that case, you first have to remove the graph from the folder manually before rerunning.*

# %%
hazard_output = root_dir / "static" / "output_graph" / "base_graph_hazard_edges.gpkg"
hazard_gdf = gpd.read_file(hazard_output, driver = "GPKG")
hazard_gdf.head()
# Out:
#            u           v  key      osmid  oneway   highway reversed  length  \
# 0  567924681  4095037852    0   44785078    True  tertiary    False    70.0
# 1  567924681   683300830    0  820923407   False  tertiary    False   529.0
# 2  567924681   567929920    0   44785077    True  tertiary    False    71.0
# 3  567929911   567932048    0   44785315    True  tertiary    False   118.0
# 4  567929911   663132500    0   52014468   False  tertiary     True   320.0
#
#                       rfid_c  rfid  ...  time  EV1_ma  EV1_fr  \
# 0               [984, 1, 41]     1  ...   4.0     0.0     0.0
# 1  [386, 388, 138, 267, 273]    45  ...  32.0     0.0     0.0
# 2              [40, 985, 28]    12  ...   4.0     0.0     0.0
# 3         [968, 824, 69, 13]     3  ...   7.0     0.0     0.0
# 4   [12, 110, 368, 370, 372]    41  ...  19.0     0.0     0.0
#
#                         name maxspeed lanes   ref junction bridge  \
# 0                        nan      nan   nan   nan      nan    nan
# 1  Ava Mártires da Revolução       60   nan   nan      nan    nan
# 2                        nan      nan   nan   nan      nan    nan
# 3           Avenida das FPLM      nan   nan   nan      nan    nan
# 4           Avenida das FPLM       60     2  1344      nan    nan
#
#                                             geometry
# 0  LINESTRING (34.87673 -19.85047, 34.87642 -19.8...
# 1  LINESTRING (34.88155 -19.84906, 34.88017 -19.8...
# 2  LINESTRING (34.87606 -19.85055, 34.87628 -19.8...
# 3  LINESTRING (34.85569 -19.84801, 34.85522 -19.8...
# 4  LINESTRING (34.85868 -19.84856, 34.85766 -19.8...
#
# [5 rows x 21 columns]

# %% [markdown]
#  A value of 0 indicates no hazard intersection. Therefore we filter these values out here

# %%
hazard_gdf = hazard_gdf[hazard_gdf['EV1_ma'] != 0]

# %% [markdown]
# Let's inspect the results visually. Below, we show the hazard values on the network for the segments affected by the hazard

# %%
hazard_gdf.explore(column="EV1_ma", cmap = "Wistia", tiles="CartoDB positron", popup = True)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ae2f8323a58ba7da9f86af2b9fa6dceb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ae2f8323a58ba7da9f86af2b9fa6dceb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ae2f8323a58ba7da9f86af2b9fa6dceb = L.map(
#                 &quot;map_ae2f8323a58ba7da9f86af2b9fa6dceb&quot;,
#                 {
#                     center: [-19.83331785, 34.86076095],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_ae2f8323a58ba7da9f86af2b9fa6dceb);
#
#
#
#
#
#             var tile_layer_a250962ab601f26c9f506a6b3cfc7f6e = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_a250962ab601f26c9f506a6b3cfc7f6e.addTo(map_ae2f8323a58ba7da9f86af2b9fa6dceb);
#
#             map_ae2f8323a58ba7da9f86af2b9fa6dceb.fitBounds(
#                 [[-19.8490569, 34.8399681], [-19.8175788, 34.8815538]],
#                 {}
#             );
#
#
#         function geo_json_128de88144f3bc08ef8c8c3df32b93e1_styler(feature) {
#             switch(feature.id) {
#                 case &quot;36&quot;: case &quot;216&quot;:
#                     return {&quot;color&quot;: &quot;#e7fc6f&quot;, &quot;fillColor&quot;: &quot;#e7fc6f&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;39&quot;:
#                     return {&quot;color&quot;: &quot;#eafa63&quot;, &quot;fillColor&quot;: &quot;#eafa63&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;53&quot;:
#                     return {&quot;color&quot;: &quot;#f2f347&quot;, &quot;fillColor&quot;: &quot;#f2f347&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;59&quot;: case &quot;182&quot;: case &quot;217&quot;:
#                     return {&quot;color&quot;: &quot;#ffa200&quot;, &quot;fillColor&quot;: &quot;#ffa200&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;60&quot;:
#                     return {&quot;color&quot;: &quot;#f2f348&quot;, &quot;fillColor&quot;: &quot;#f2f348&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;61&quot;:
#                     return {&quot;color&quot;: &quot;#ffba00&quot;, &quot;fillColor&quot;: &quot;#ffba00&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;63&quot;:
#                     return {&quot;color&quot;: &quot;#f0f550&quot;, &quot;fillColor&quot;: &quot;#f0f550&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;64&quot;: case &quot;218&quot;:
#                     return {&quot;color&quot;: &quot;#ecf95f&quot;, &quot;fillColor&quot;: &quot;#ecf95f&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;65&quot;: case &quot;183&quot;:
#                     return {&quot;color&quot;: &quot;#fe9800&quot;, &quot;fillColor&quot;: &quot;#fe9800&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;66&quot;: case &quot;68&quot;:
#                     return {&quot;color&quot;: &quot;#fe9400&quot;, &quot;fillColor&quot;: &quot;#fe9400&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;67&quot;:
#                     return {&quot;color&quot;: &quot;#ffa000&quot;, &
